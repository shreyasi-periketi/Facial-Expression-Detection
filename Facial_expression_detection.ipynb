# %%
import cv2

# %%
img = cv2.imread("C:/Users/HP/Desktop/College Projects/Summer Internship/images_SI/happy.jpg")

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
from deepface import DeepFace

# %%
predictions = DeepFace.analyze(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 predictions = DeepFace.analyze(img)
#
# NameError: name 'DeepFace' is not defined

# %%
predictions
# Out:
# {'emotion': {'angry': 9.41034472567992e-08,
#   'disgust': 6.584409953736814e-15,
#   'fear': 2.6328226709892988e-06,
#   'happy': 99.97302889823914,
#   'sad': 1.2724070685976585e-06,
#   'surprise': 0.02498239919077605,
#   'neutral': 0.001996059472730849},
#  'dominant_emotion': 'happy',
#  'region': {'x': 1045, 'y': 1043, 'w': 1558, 'h': 1558},
#  'age': 28,
#  'gender': 'Woman',
#  'race': {'asian': 0.9577392600476742,
#   'indian': 0.5126440431922674,
#   'black': 0.04571763565763831,
#   'white': 72.19924926757812,
#   'middle eastern': 11.14371195435524,
#   'latino hispanic': 15.140938758850098},
#  'dominant_race': 'white'}
